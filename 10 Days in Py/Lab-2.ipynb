# %% [markdown]
# **Control Statement**

# %% [markdown]
#  A class of 10 students took a quiz. Their grades (integers in the range 0 – 100) are 98, 76, 71, 87, 83, 90, 57, 79, 82, 94. Determine the class average on the quiz.

# %%
total = 0
grades = [98, 76, 71, 87, 83, 90, 57, 79, 82, 94]

for grade in grades:
  total = total+grade

average = total/len(grades)
print(average)
print(f'Average is {average}')
# Out:
# 81.7
# Average is 81.7

# %% [markdown]
# **F-String**

# %%
name = "OOP Lab"
code = 222

print(f'This is {name} and Course Code is {code}')
# Out:
# This is OOP Lab and Course Code is 222

# %% [markdown]
# **Sentinel-Controlled Solving**

# %%
total = 0
counter = 0

grade = int(input("Enter grade, -1 to end: "))
while grade != -1:
  total = total+grade
  counter = counter+1
  grade = int(input("Enter grade, -1 to end: "))

average = total/counter
print(average)
print(f'Average is {average}')
# Out:
# Enter grade, -1 to end: 78
# Enter grade, -1 to end: 89
# Enter grade, -1 to end: 90
# Enter grade, -1 to end: 76
# Enter grade, -1 to end: -1
# 83.25
# Average is 83.25

# %%
total = 0
counter = 0

mark = int(input("Enter mark, -1 to end: "))
while mark != -1:
  total = total+mark
  counter = counter+1
  mark = int(input("Enter mark, -1 to end: "))

average = total/counter
print(f'Average mark is {average}')
# Out:
# Enter mark, -1 to end: 90
# Enter mark, -1 to end: 89
# Enter mark, -1 to end: 99
# Enter mark, -1 to end: 89
# Enter mark, -1 to end: -1
# Average mark is 91.75

# %% [markdown]
# **Nested Control Statement**

# %% [markdown]
# *  A college offers a course that prepares students for the IELTS exam.
# *  Last year, several of the students who completed this course took the IELTS
# exam.
# *  The college wants to know how well their students did on the exam.
# *  You have been asked to write a program to summarize the results.
# *  You have been given a list of 10 students.
# *  Next to each name is written a 1 if the student passed the exam and a 2 if
# the student failed.
# *  If more than six students passed the exam, the instructor can get bonus.

# %%
passes = 0
fails = 0

for number in range(10):
  result = int(input("Enter result: 1 for Pass and 2 for Fail: "))

  if result==1:
    passes = passes+1
  else:
    fails = fails+1

print(f'Total {passes} students passed and {fails} failed!')

if passes > 6:
  print("Teacher will get bonus!")
else:
  print("Teacher will not get bonus!")
# Out:
# Enter result: 1 for Pass and 2 for Fail: 1
# Enter result: 1 for Pass and 2 for Fail: 1
# Enter result: 1 for Pass and 2 for Fail: 1
# Enter result: 1 for Pass and 2 for Fail: 1
# Enter result: 1 for Pass and 2 for Fail: 2
# Enter result: 1 for Pass and 2 for Fail: 2
# Enter result: 1 for Pass and 2 for Fail: 1
# Enter result: 1 for Pass and 2 for Fail: 1
# Enter result: 1 for Pass and 2 for Fail: 1
# Enter result: 1 for Pass and 2 for Fail: 1
# Total 8 students passed and 2 failed!
# Teacher will get bonus!

# %% [markdown]
# **Functions in Python**

# %%
def sum(a, b):
  c = a + b
  return c

def square(a):
  return a**2

sum(3, 4)
sq = square(2)
