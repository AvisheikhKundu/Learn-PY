# %% [markdown]
# **Dictionary**

# %%
city = dict()

# %%
student = dict()

# %%
student[5757] = 'Nahid'
student[5457] = 'Mehbub'
student
# Out:
# {5757: 'Nahid', 5457: 'Mehbub'}

# %%
student[5757]
# Out:
# 'Nahid'

# %%
student.update({5457: 'VRC'})

# %%
student
# Out:
# {5757: 'Nahid', 5457: 'VRC'}

# %%
student.update({4930: 'Shathi'})

# %%
student
# Out:
# {5757: 'Nahid', 5457: 'VRC', 4930: 'Shathi'}

# %%
for key, value in student.items():
  print(f'{value} has {key} id')
# Out:
# Nahid has 5757 id
# VRC has 5457 id
# Shathi has 4930 id

# %%
del student[5457]

# %%
student
# Out:
# {5757: 'Nahid', 4930: 'Shathi'}

# %% [markdown]
# **Set**

# %%
colors = set()
colors = {'red', 'blue', 'green', 'lilac', 'green'}
colors
# Out:
# {'blue', 'green', 'lilac', 'red'}

# %%
'lilac' in colors
# Out:
# True

# %%
colors.add('purple')
colors
# Out:
# {'blue', 'green', 'lilac', 'purple', 'red'}

# %%
colors.remove('lilac')
colors
# Out:
# {'blue', 'green', 'purple', 'red'}

# %%
{1,6}.issubset({1,2,3})
# Out:
# False
